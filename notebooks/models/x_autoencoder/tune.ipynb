# %%
from lab_scripts.utils import utils
utils.change_directory_to_repo()

import pandas as pd
from ray import tune

# %%
result = tune.Analysis('/home/simon/nips/tune/tune_one_config_2021-10-15_23-26-53')

# %%
result.dataframe()
# Out:
#    true_1_to_2  true_2_to_1        11        12        21        22  \
# 0     0.534068     0.299052  0.067556  0.148467  0.036007  0.067659
# 1     0.551410     0.308978  0.091909  0.130863  0.048449  0.068308
#
#    time_this_iter_s   done  timesteps_total  episodes_total  ...    pid  \
# 0         21.524242  False              NaN             NaN  ...  15226
# 1         20.317437  False              NaN             NaN  ...  15214
#
#                         hostname       node_ip  time_since_restore  \
# 0  simon-ROG-Strix-G531GW-G531GW  192.168.1.41           21.524242
# 1  simon-ROG-Strix-G531GW-G531GW  192.168.1.41           20.317437
#
#    timesteps_since_restore  iterations_since_restore     trial_id  \
# 0                        0                         1  3c0d1_00000
# 1                        0                         1  3c0d1_00001
#
#                                          config/data  \
# 0  {'dataset_name': 'mp/official/gex_to_adt', 'mo...
# ...
