# %%
import anndata as ad
import scanpy as sc
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from lab_scripts.utils import utils
utils.change_directory_to_repo()

from lab_scripts.data import dataloader

sc.settings.verbosity = 3  # show info messages
sc.set_figure_params(figsize=(5, 3))  # set figsize for plots

# %%
data = dataloader.load_data('mp/official/gex_to_adt')

# %%
train_adt = data['train_mod2']

# %%
train_adt
# Out:
# AnnData object with n_obs × n_vars = 29077 × 134
#     obs: 'batch'
#     var: 'feature_types'
#     uns: 'dataset_id'
#     layers: 'counts'

# %%
X = train_adt.X.toarray()

# %%
flat = X.flatten()
sns.histplot(flat[::101])
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(X.sum(axis=1))
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.histplot(X.sum(axis=0))
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
counts = train_adt.layers['counts'].toarray()
plain_counts = counts[:, 30:35]

# %%
counts.mean()
# Out:
# 13.951833756895613

# %%
plt.hist(plain_counts[plain_counts < 1000], bins=500)
# Out:
# (array([4.1998e+04, 4.0674e+04, 2.5620e+04, 1.2929e+04, 6.5120e+03,
#         3.9150e+03, 2.6290e+03, 1.8360e+03, 1.3840e+03, 9.7600e+02,
#         7.9100e+02, 6.4300e+02, 5.3000e+02, 4.2000e+02, 3.3900e+02,
#         2.8400e+02, 2.2900e+02, 2.1800e+02, 1.7600e+02, 1.7000e+02,
#         1.4400e+02, 1.3000e+02, 1.2000e+02, 1.1000e+02, 9.9000e+01,
#         8.1000e+01, 7.8000e+01, 7.4000e+01, 5.8000e+01, 6.9000e+01,
#         6.1000e+01, 5.3000e+01, 4.1000e+01, 2.4000e+01, 5.2000e+01,
#         3.5000e+01, 4.8000e+01, 5.1000e+01, 3.6000e+01, 4.3000e+01,
#         2.3000e+01, 3.1000e+01, 2.9000e+01, 1.9000e+01, 2.6000e+01,
#         2.8000e+01, 1.7000e+01, 2.1000e+01, 2.6000e+01, 3.1000e+01,
#         1.5000e+01, 2.0000e+01, 1.4000e+01, 1.4000e+01, 1.2000e+01,
#         1.9000e+01, 2.0000e+01, 1.4000e+01, 1.2000e+01, 1.5000e+01,
#         1.9000e+01, 1.6000e+01, 1.8000e+01, 1.5000e+01, 2.5000e+01,
#         1.9000e+01, 6.0000e+00, 1.0000e+01, 1.1000e+01, 1.1000e+01,
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(counts.flatten()[::1013])
# Out:
# (array([3.845e+03, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([    0. ,  1180.8,  2361.6,  3542.4,  4723.2,  5904. ,  7084.8,
#          8265.6,  9446.4, 10627.2, 11808. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.violinplot(counts)
# Out:
# /home/simon/miniconda3/envs/nips/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>
