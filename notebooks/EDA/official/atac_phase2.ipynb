# %%
import anndata as ad
import scanpy as sc
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from lab_scripts.utils import utils
utils.change_directory_to_repo()

# %%
adt_common = ad.read_h5ad('data/official/common_v1/openproblems_bmmc_multiome_phase1/openproblems_bmmc_multiome_phase1.manual_formatting.output_mod2.h5ad')

# %%
adt_common.obs['batch'].value_counts()
# Out:
# s1d2    6069
# s1d1    5616
# s2d4    5456
# s2d1    3811
# s3d6    1511
# Name: batch, dtype: int64

# %%
adt_common.obs['norm_sum'] = adt_common.X.sum(axis=1)
sc.pl.violin(adt_common, keys='norm_sum', groupby='batch')

# %%
adt_common.obs['raw_sum'] = adt_common.layers['counts'].sum(axis=1)
sc.pl.violin(adt_common, keys='raw_sum', groupby='batch')

# %%
old_adt = ad.read_h5ad('data/official/common_v1/openproblems_bmmc_multiome_phase1/openproblems_bmmc_multiome_phase1.manual_formatting.output_rna.h5ad')

# %%
old_adt.obs['norm_sum'] = old_adt.X.sum(axis=1)
sc.pl.violin(old_adt, keys='norm_sum', groupby='batch')

# %%
old_adt.obs['raw_sum'] = old_adt.layers['counts'].sum(axis=1)
sc.pl.violin(old_adt, keys='raw_sum', groupby='batch')
