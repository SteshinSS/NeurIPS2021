# %% [markdown]
# # EDA of the official gex/atac dataset
# Work in progress

# %%
import anndata as ad
import numpy as np
import pandas as pd
import scanpy as sc

from lab_scripts.utils import utils
utils.change_directory_to_repo()
from lab_scripts.data import dataloader

# %%
gex = ad.read_h5ad("data/official/common/openproblems_bmmc_multiome_phase1/openproblems_bmmc_multiome_phase1.manual_formatting.output_rna.h5ad")
gex = gex[gex.obs['is_train'], :]

# %%
gex.obs.describe()
# Out:
#        n_genes_by_counts  pct_counts_mt      n_counts       n_genes  \
# count       16394.000000   16394.000000  16394.000000  16394.000000
# mean         1343.648042       0.539817   2434.480664   1343.648042
# std           721.854131       0.632205   1894.733065    721.854131
# min           242.000000       0.000000    414.000000    242.000000
# 25%           890.000000       0.144928   1345.000000    890.000000
# 50%          1188.000000       0.307193   1898.000000   1188.000000
# 75%          1600.000000       0.746269   2830.000000   1600.000000
# max          6558.000000      11.470362  23997.000000   6558.000000
#
#        size_factors  pseudotime_order_GEX  pseudotime_order_ATAC
# count  16394.000000           4440.000000            4440.000000
# mean       0.683143              0.842272               0.777326
# std        0.585593              0.209891               0.164569
# min        0.050273              0.000000               0.000000
# ...
