# %%
import anndata as ad
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from lab_scripts.utils import utils
utils.change_directory_to_repo()

# %%
gex = ad.read_h5ad('data/official/common/openproblems_bmmc_multiome_phase1v2/openproblems_bmmc_multiome_phase1v2.manual_formatting.output_rna.h5ad')

# %%
gex.obs['raw_total'] = gex.layers['counts'].sum(axis=1)
sc.pl.violin(gex, keys='raw_total', groupby='batch')

# %%
gex.obs['total'] = gex.X.sum(axis=1)
sc.pl.violin(gex, keys='total', groupby='batch')

# %%
adt_gex = ad.read_h5ad('data/official/common/openproblems_bmmc_cite_phase1v2/openproblems_bmmc_cite_phase1v2.manual_formatting.output_rna.h5ad')

# %%
adt_gex.obs['raw_total'] = adt_gex.layers['counts'].sum(axis=1)
sc.pl.violin(adt_gex, keys='raw_total', groupby='batch')

# %%
adt_gex.obs['total'] = adt_gex.X.sum(axis=1)
sc.pl.violin(adt_gex, keys='total', groupby='batch')
