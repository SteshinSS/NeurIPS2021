# %%
import anndata as ad
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import scanpy as sc
import scib
from lab_scripts.utils import utils
utils.change_directory_to_repo()

# %%
data = ad.read_h5ad('data/official/joint_embedding/openproblems_bmmc_cite_phase2/openproblems_bmmc_cite_phase2.censor_dataset.output_solution.h5ad')

# %%
scib.preprocessing.score_cell_cycle(data, 'human')

# %%
data.obs['S_score'].mean()
# Out:
# -0.01072746601265183

# %%
x = [0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9]
y1 = [0.0461, 0.0531, 0.0614, 0.0711, 0.0821, 0.094, 0.107, 0.121, 0.136, 0.152, 0.169, 0.186, 0.204, 0.222, 0.240, 0.258, 0.277]
y2 = [0.0163, 0.0183, 0.020, 0.023, 0.0273, 0.0313,0.035, 0.040, 0.0461, 0.0520, 0.0584, 0.0653, 0.072, 0.0804, 0.0886, 0.0973, 0.106]
y3 = [0.055, 0.059, 0.065, 0.071, 0.078]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
x = np.array(x)
x = x.reshape(-1, 1)
lr.fit(x, y1)
# Out:
# LinearRegression()

# %%
lr.score(x, y1)
# Out:
# 0.9861622123773985

# %%
plt.plot(x, y2)

# %%
plt.plot(x, y3)
